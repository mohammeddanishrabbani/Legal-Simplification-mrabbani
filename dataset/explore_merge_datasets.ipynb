# %%
import pandas as pd

new_dataset = pd.read_csv('INDIAN_LAW_DATASET.csv')

len(new_dataset)
# Out:
# 4104

# %%
old_dataset = pd.read_csv('simplification_final_dataset.csv')
len(old_dataset)
# Out:
# 2126

# %%
#merge the two datasets
merged_dataset = pd.concat([old_dataset, new_dataset], ignore_index=True)

#save the merged dataset to a new csv file
merged_dataset.to_csv('merged_dataset.csv', index=False)
len(merged_dataset)
# Out:
# 6230
